# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
#img = cv2.imread('/home/img/python.png')
img = cv2.imread('../data-capstone/fer2013_2/train/angry/Training_178362.jpg')
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = mpimg.imread('../data-capstone/fer2013_2/train/angry/Training_178362.jpg')
imgplot = plt.imshow(img)
plt.show()
